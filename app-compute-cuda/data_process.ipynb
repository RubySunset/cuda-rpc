# %%
## auto mod = vctx->make_module_data(mem_so, module_file).get(); // data mem_so
        

import numpy as np
# Read the file content
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/service.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
server_times = []
for line in lines:
    if "time for load module server" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            server_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(server_times)
# print(server_times[1:-2])
print(len(server_times[1:-2]))
average_time = np.mean(server_times[1:-2])
std_deviation = np.std(server_times[1:-2])

print(f"Server - load module -  Average time: {average_time}")
print(f"Server - load module - Standard deviation: {std_deviation}")

with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for load module client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - load module - Average time: {average_time}")
print(f"Client - load module - Standard deviation: {std_deviation}")
print(f"==================================================")

## auto func = mod->get_function(func_name).get();

import numpy as np
# Read the file content
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/service.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
server_times = []
for line in lines:
    if "time for get function server" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            server_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(server_times[1:])
print(len(server_times[1:-1]))
average_time = np.mean(server_times[1:-1])
std_deviation = np.std(server_times[1:-1])

print(f"Server - get function -  Average time: {average_time}")
print(f"Server - get function - Standard deviation: {std_deviation}")

with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for get function client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - get function - Average time: {average_time}")
print(f"Client - get function - Standard deviation: {std_deviation}")
print(f"==================================================")

## time for launch kernel server
## func->call(grid, mem_a_addr, mem_b_addr, mem_r_addr, N).get(); // *stream

import numpy as np
# Read the file content
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/service.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
server_times = []
for line in lines:
    if "time for launch kernel server" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            server_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(server_times[1:])
print(len(server_times[1:]))
average_time = np.mean(server_times[1:])
std_deviation = np.std(server_times[1:])

print(f"Server - launch kernel -  Average time: {average_time}")
print(f"Server - launch kernel - Standard deviation: {std_deviation}")

with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for launch kernel client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - launch kernel - Average time: {average_time}")
print(f"Client - launch kernel - Standard deviation: {std_deviation}")
print(f"==================================================")
# Out:
# 30
# Server - load module -  Average time: 87.86666666666666
# Server - load module - Standard deviation: 2.9066972475455524
# 30
# Client - load module - Average time: 167.03333333333333
# Client - load module - Standard deviation: 5.281939879333056
# ...
# 30
# Server - get function -  Average time: 9.633333333333333
# Server - get function - Standard deviation: 0.48189440982669873
# 30
# Client - get function - Average time: 79.7
# Client - get function - Standard deviation: 2.59679289380831
# ...
# 30
# Server - launch kernel -  Average time: 17.3
# Server - launch kernel - Standard deviation: 0.5259911279353167
# 30
# Client - launch kernel - Average time: 36.266666666666666
# Client - launch kernel - Standard deviation: 1.2631530214330944
# ...

# %%
## auto mem_a = vctx->make_memory(size).get();

## auto mem_a = vctx->make_memory(size).get();

import numpy as np
# Read the file content
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/service.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
server_times = []
for line in lines:
    if "time for cumemalloc server" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            server_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(server_times)
# print(server_times[1:-2])
print(len(server_times[1:-2]))
average_time = np.mean(server_times[1:-2])
std_deviation = np.std(server_times[1:-2])

print(f"Server - device alloc - Average time: {average_time}")
print(f"Server - device alloc - Standard deviation: {std_deviation}")

import numpy as np
# Read the file content
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for device alloc client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - device alloc - Average time: {average_time}")
print(f"Client - device alloc - Standard deviation: {std_deviation}")
print(f"==================================================")

## vctx->make_memory_rpc_test(size).get();

import numpy as np
# Read the file content
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/service.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
server_times = []
for line in lines:
    if "test rpc client time" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            server_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(server_times[1:])
print(len(server_times[1:]))
average_time = np.mean(server_times[1:])
std_deviation = np.std(server_times[1:])

print(f"Server - rpc -  Average time: {average_time}")
print(f"Server - rpc - Standard deviation: {std_deviation}")

with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for rpc test client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - rpc - Average time: {average_time}")
print(f"Client - rpc - Standard deviation: {std_deviation}")
print(f"==================================================")

## int* h_A = (int*)malloc(size);
# for (size_t i = 0; i < N; ++i) {
#     h_A[i] = static_cast<int>(i);
# }
# auto mr_A = ch->make_memory_region(h_A, size, core::memory_region::translation_type::PIN);
# auto mem_a_local = ch->make_memory(h_A, size, *mr_A).get(); // ?

import numpy as np
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for host alloc client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - host alloc - Average time: {average_time}")
print(f"Client - host alloc - Standard deviation: {std_deviation}")
print(f"==================================================")

## ch->copy(mem_a_local, mem_a->get_cap_mem()).get();
## ch->copy(mem_a->get_cap_mem(), mem_a_local).get();
import numpy as np
with open('/home/mingxuanyang/fractos/experiments/run/app-compute-cuda/logs/localhost-simple--_/benchmark.log', 'r') as file:
    lines = file.readlines()

# Extract server times from the file content
client_times = []
for line in lines:
    if "time for copy device2host + host2device client" in line:
        parts = line.split()
        try:
            time = int(parts[-1])
            client_times.append(time)
        except ValueError:
            continue
# Calculate average and standard deviation
# print(client_times)
print(len(client_times))
average_time = np.mean(client_times)
std_deviation = np.std(client_times)

print(f"Client - copy*2 - Average time: {average_time}")
print(f"Client - copy*2 - Standard deviation: {std_deviation}")
print(f"==================================================")
# Out:
# 30
# Server - device alloc - Average time: 575.3666666666667
# Server - device alloc - Standard deviation: 46.807751020056024
# 30
# Client - device alloc - Average time: 658.6
# Client - device alloc - Standard deviation: 46.88610312946328
# ...
# 30
# Server - rpc -  Average time: 8.1
# Server - rpc - Standard deviation: 0.3
# 30
# Client - rpc - Average time: 35.56666666666667
# Client - rpc - Standard deviation: 2.836468853267308
# ...
# 30
# Client - host alloc - Average time: 1398.7666666666667
# Client - host alloc - Standard deviation: 83.31893875677699
# ...
# 30
# Client - copy*2 - Average time: 2155.6666666666665
# Client - copy*2 - Standard deviation: 111.08565263895345
# ...
